# %%
import torch
import torch.nn as nn
import matplotlib.pyplot as plt
from torch.utils.data import Dataset,DataLoader
import torchvision.transforms as transforms
from  torchvision.datasets import ImageFolder
from torch.autograd import Variable
import cv2
import numpy as np
import os, random,sys

# %% [markdown]
# # Build an Autoencoder for a human face dataset
#
# We will use a dataset containig images of people and train an autoencoder on it.
#
# ## Step 1
#
# Download and unzip the ``lfw.zip`` file . Adjust the ``path`` variable so that it contains the address of the unzipped folder. We will create a dataloader from this folder.

# %%
path = 'lfw'

# %%
transform = transforms.Compose([transforms.Resize((256, 256)), transforms.ToTensor()])
dataloader = DataLoader(ImageFolder(path, transform,),batch_size=32, shuffle=True)

# %% [markdown]
# This project is compute intensive. If you have a cuda or mps device on your laptop make sure you use that in the training.

# %%
if torch.backends.mps.is_available():
    device = torch.device("mps")
else:
    print ("MPS device not found.")

# %%
for x,y in dataloader:
    x = x[0].permute(1, 2, 0)
    print(x.shape)
    plt.imshow(x)
    break
# Out:
# torch.Size([256, 256, 3])

# %% [markdown]
# ## Step 2
# Each datapoint is an image. Get a sample of the data and print its dimensions and explain what each dimension means.

# %%
# Step 2: Get a sample from the dataloader and print its dimensions

# Iterate over the dataloader to get a sample
for x, y in dataloader:
    # Display the dimensions of the sample
    print(f"Sample Dimensions: {x.shape}")
    
    # Explain each dimension
    batch_size, channels, height, width = x.shape
    print(f"Batch Size: {batch_size}")
    print(f"Number of Channels: {channels}")
    print(f"Image Height: {height}")
    print(f"Image Width: {width}")
    
    # Break the loop after the first iteration
    break
# Out:
# Sample Dimensions: torch.Size([32, 3, 256, 256])
# Batch Size: 32
# Number of Channels: 3
# Image Height: 256
# Image Width: 256

# %% [markdown]
# # Step 3
#
# Create a new pytorch model calss for your autoencoder. You can use Conv2d, MaxPool2d, BatchNorm2d, ConvTranspose2d and Linear Layers as as well as activation functions. Optionally, you can use UpSample, AveragePool2d and Interpolate2d as well.
#
# **Create seperate functions for the encoder and decoder.**

# %%
import torch.nn.functional as F

class AE(nn.Module):
    def __init__(self):
        super(AE, self).__init__()
        
        # Encoder layers
        self.encoder_conv1 = nn.Conv2d(3, 32, kernel_size=3, stride=2, padding=1)
        self.encoder_bn1 = nn.BatchNorm2d(32)
        self.encoder_conv2 = nn.Conv2d(32, 64, kernel_size=3, stride=2, padding=1)
        self.encoder_bn2 = nn.BatchNorm2d(64)
        self.encoder_conv3 = nn.Conv2d(64, 128, kernel_size=3, stride=2, padding=1)
        self.encoder_bn3 = nn.BatchNorm2d(128)
        
        # Decoder layers
         self.decoder_conv1 = nn.ConvTranspose2d(32, 3, kernel_size=3, stride=2, padding=1, output_padding=1)
        self.decoder_bn1 = nn.BatchNorm2d(64)
        self.decoder_conv2 = nn.ConvTranspose2d(64, 32, kernel_size=3, stride=2, padding=1, output_padding=1)
        self.decoder_bn2 = nn.BatchNorm2d(32)
        self.decoder_conv3 = nn.ConvTranspose2d(32, 3, kernel_size=3, stride=2, padding=1, output_padding=1)
        self.decoder_bn3 = nn.BatchNorm2d(3)

    def encoder(self, x):
        x = F.relu(self.encoder_bn1(self.encoder_conv1(x)))
        x = F.relu(self.encoder_bn2(self.encoder_conv2(x)))
        x = F.relu(self.encoder_bn3(self.encoder_conv3(x)))
        return x

    def decoder(self, x):
        x = F.relu(self.decoder_bn1(self.decoder_conv1(x)))
        x = F.relu(self.decoder_bn2(self.decoder_conv2(x)))
        x = torch.sigmoid(self.decoder_bn3(self.decoder_conv3(x)))
        return x

    def forward(self, x):
        x = self.encoder(x)
        x = self.decoder(x)
        return x

# Create an instance of the AE model
autoencoder = AE()

# %% [markdown]
# ## Step 4
# Create an instance of the class, pass an image to the model, print the shape of the output of the **encoder** and the **decoder**. Check the dimensions and make sure your forward path is working properly.

# %%
# Step 4: Create an instance of the class, pass an image, and print shapes of encoder and decoder outputs

# Set the model to MPS device explicitly
autoencoder.to('mps')

# Reshape the sample image to include a batch dimension
sample_image = sample_image.unsqueeze(0)

# Convert the sample image to MPS explicitly
sample_image = Variable(sample_image).to('mps')

# Pass the sample image through the autoencoder
encoded_output = autoencoder.encoder(sample_image)
decoded_output = autoencoder.decoder(encoded_output)



# Print the shapes of encoder and decoder outputs
print(f"Shape of Encoder Output: {encoded_output.shape}")
print(f"Shape of Decoder Output: {decoded_output.shape}")
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# /var/folders/h8/rbzftw4n6md8gn35cwd7qrlc0000gn/T/ipykernel_43650/3258356955.py in <module>
#      11
#      12 # Pass the sample image through the autoencoder
# ---> 13 encoded_output = autoencoder.encoder(sample_image)
#      14 decoded_output = autoencoder.decoder(encoded_output)
#      15
#
# /var/folders/h8/rbzftw4n6md8gn35cwd7qrlc0000gn/T/ipykernel_43650/2362053863.py in encoder(self, x)
#      22
#      23     def encoder(self, x):
# ---> 24         x = F.relu(self.encoder_bn1(self.encoder_conv1(x)))
#      25         x = F.relu(self.encoder_bn2(self.encoder_conv2(x)))
#      26         x = F.relu(self.encoder_bn3(self.encoder_conv3(x)))
#
# ~/opt/anaconda3/lib/python3.9/site-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1516             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517         else:
# -> 1518             return self._call_impl(*args, **kwargs)
#    1519
#    1520     def _call_impl(self, *args, **kwargs):
#
# ~/opt/anaconda3/lib/python3.9/site-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1525                 or _global_backward_pre_hooks or _global_backward_hooks
#    1526                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527             return forward_call(*args, **kwargs)
#    1528
#    1529         try:
#
# ~/opt/anaconda3/lib/python3.9/site-packages/torch/nn/modules/conv.py in forward(self, input)
#     458
#     459     def forward(self, input: Tensor) -> Tensor:
# --> 460         return self._conv_forward(input, self.weight, self.bias)
#     461
#     462 class Conv3d(_ConvNd):
#
# ~/opt/anaconda3/lib/python3.9/site-packages/torch/nn/modules/conv.py in _conv_forward(self, input, weight, bias)
#     454                             weight, bias, self.stride,
#     455                             _pair(0), self.dilation, self.groups)
# --> 456         return F.conv2d(input, weight, bias, self.stride,
#     457                         self.padding, self.dilation, self.groups)
#     458
#
# RuntimeError: Expected 3D (unbatched) or 4D (batched) input to conv2d, but got input of size: [1, 1, 3, 250, 250]

# %% [markdown]
# ##  Step 5
# Print total number of parameters in the model, explain what loss function you should use, create an optimizer for training

# %%
total_params = sum(p.numel() for p in autoencoder.parameters())
print(f"Total number of parameters in the model: {total_params}")
criterion = nn.MSELoss()
# Out:
# Total number of parameters in the model: 187017

# %%
optimizer = torch.optim.Adam(autoencoder.parameters(), lr=0.001)

# %%
num_epochs = 10

for epoch in range(num_epochs):
    for data in dataloader:
        inputs, _ = data
        inputs = inputs.to('mps')  # Move data to MPS device if needed

        optimizer.zero_grad()

        outputs = autoencoder(inputs)
        loss = criterion(outputs, inputs)

        loss.backward()
        optimizer.step()

    print(f'Epoch [{epoch + 1}/{num_epochs}], Loss: {loss.item()}')
# Out:
# /Users/kenilvaghasiya704/opt/anaconda3/lib/python3.9/site-packages/torch/nn/modules/loss.py:535: UserWarning: Using a target size (torch.Size([32, 3, 250, 250])) that is different to the input size (torch.Size([32, 3, 256, 256])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# /var/folders/h8/rbzftw4n6md8gn35cwd7qrlc0000gn/T/ipykernel_43650/1062803330.py in <module>
#       9
#      10         outputs = autoencoder(inputs)
# ---> 11         loss = criterion(outputs, inputs)
#      12
#      13         loss.backward()
#
# ~/opt/anaconda3/lib/python3.9/site-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1516             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517         else:
# -> 1518             return self._call_impl(*args, **kwargs)
#    1519
#    1520     def _call_impl(self, *args, **kwargs):
#
# ~/opt/anaconda3/lib/python3.9/site-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1525                 or _global_backward_pre_hooks or _global_backward_hooks
#    1526                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527             return forward_call(*args, **kwargs)
#    1528
#    1529         try:
#
# ~/opt/anaconda3/lib/python3.9/site-packages/torch/nn/modules/loss.py in forward(self, input, target)
#     533
#     534     def forward(self, input: Tensor, target: Tensor) -> Tensor:
# --> 535         return F.mse_loss(input, target, reduction=self.reduction)
#     536
#     537
#
# ~/opt/anaconda3/lib/python3.9/site-packages/torch/nn/functional.py in mse_loss(input, target, size_average, reduce, reduction)
#    3326         reduction = _Reduction.legacy_get_string(size_average, reduce)
#    3327
# -> 3328     expanded_input, expanded_target = torch.broadcast_tensors(input, target)
#    3329     return torch._C._nn.mse_loss(expanded_input, expanded_target, _Reduction.get_enum(reduction))
#    3330
#
# ~/opt/anaconda3/lib/python3.9/site-packages/torch/functional.py in broadcast_tensors(*tensors)
#      71     if has_torch_function(tensors):
#      72         return handle_torch_function(broadcast_tensors, tensors, *tensors)
# ---> 73     return _VF.broadcast_tensors(tensors)  # type: ignore[attr-defined]
#      74
#      75
#
# RuntimeError: The size of tensor a (256) must match the size of tensor b (250) at non-singleton dimension 3

# %% [markdown]
# ##  Step 6
# Write a training loop and start trainng the model for several epochs. Report the loss value at the end of each epoch and monitor it. If your loss is not decreasing what do you have to do to troubleshoot it ?

# %% [markdown]
# ##  Step 7
#
# Take a random image from the dataset and plot it against the reconstructed (encoded + decoded) image.

# %%
plt.imshow()

# %% [markdown]
# ##  Step 8
#
# In step 7, add a small normaly distrubuted noise to the latent (hidden) representation of the input image and then decode it again. How is adding noise affecting the decoded image ?
